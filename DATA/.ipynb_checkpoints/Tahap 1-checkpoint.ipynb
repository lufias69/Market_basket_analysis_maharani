# %%
import pandas as pd

# %%
import os

path = r'D:\github\python\sona\DATA\all'

files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.xls' in file:
            files.append(os.path.join(r, file))

files:
# Out:
# []

# %%
barang_tr = list()
tanggal_tr = list()
transaksi = list()

for al in alamat:
    al = folder+"/"+al
    foo = pd.read_excel(al)
    tangal = foo["Maharani"].tolist()
    nomer_transaksi = foo["Unnamed: 2"].tolist()
    nama_barang = foo["Unnamed: 3"].tolist()
    for i, j, k in zip(tangal, nomer_transaksi, nama_barang):
        if j != "nan ": #and i == "nan":
    #         print(i, "|",j,"|", k)
            if type(i) is not float:
                if type(i) == int:
    #                 print(i)
                    transaksi.append(k)
                elif type(i) is str:
    #                 print(i)
                    barang_tr.append(transaksi)
                    tanggal_tr.append(i)
                    transaksi=list()

    #             print(i, "|",j,"|", k)
    #             print(type(i))
    #     print(i, "|",j,"|", k)
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
#                                   Maharani   Unnamed: 1          Unnamed: 2  \
# 0     Laporan Data Penjualan Per Transaksi          NaN                 NaN
# 1            Tanggal cetak : 08 April 2019          NaN                 NaN
# 2                                  Tanggal          NaN        No.Transaksi
# 3                                      NaN  Kode Barang                 NaN
# 4                               01/01/2016          NaN  003012016010100096
# 5                                        1      1210359                 NaN
# 6                                      NaN          NaN                 NaN
# 7                                        2      1210992                 NaN
# 8                                        3      1210164                 NaN
# 9                                      NaN          NaN                 NaN
# 10                                     NaN          NaN                 NaN
# 11                              01/01/2016          NaN  003012016010100097
# 12                                       1      1210963                 NaN
# 13                                     NaN          NaN                 NaN
# 14                                     NaN          NaN                 NaN
# 15                              01/01/2016          NaN  003012016010100098
# 16                                       1      2010734                 NaN
# 17                                     NaN          NaN                 NaN
# 18                                       2      2010013                 NaN
# 19                                     NaN          NaN                 NaN
# 20                                       3      4610097                 NaN
# 21                                     NaN          NaN                 NaN
# 22                                       4      2010057                 NaN
# 23                                       5      3210017                 NaN
# 24                                       6      2210323                 NaN
# 25                                       7      1711795                 NaN
# 26                                     NaN          NaN                 NaN
# 27                                     NaN          NaN                 NaN
# 28                              01/01/2016          NaN  003012016010100099
# 29                                       1       910005                 NaN
# ...                                    ...          ...                 ...
# 9444                                   NaN          NaN                 NaN
# 9445                                     2      8294359                 NaN
# 9446                                     3      1910492                 NaN
# 9447                                   NaN          NaN                 NaN
# 9448                                     4      2010442                 NaN
# 9449                                     5      3410477                 NaN
# 9450                                   NaN          NaN                 NaN
# 9451                                     6      4610130                 NaN
# 9452                                     7      3410793                 NaN
# 9453                                   NaN          NaN                 NaN
# 9454                                     8       221185                 NaN
# 9455                                   NaN          NaN                 NaN
# 9456                                   NaN          NaN                 NaN
# 9457                              Maharani          NaN                 NaN
# 9458  Laporan Data Penjualan Per Transaksi          NaN                 NaN
# 9459         Tanggal cetak : 08 April 2019          NaN                 NaN
# 9460                               Tanggal          NaN        No.Transaksi
# 9461                                   NaN  Kode Barang                 NaN
# 9462                                     9       810002                 NaN
# 9463                                    10      1210991                 NaN
# 9464                                    11      2513700                 NaN
# 9465                                   NaN          NaN                 NaN
# 9466                                    12      1410585                 NaN
# 9467                                    13       710081                 NaN
# 9468                                    14      1910454                 NaN
# 9469                                   NaN          NaN                 NaN
# 9470                                    15       710422                 NaN
# 9471                                   NaN          NaN                 NaN
# 9472                                   NaN          NaN                 NaN
# 9473                                   NaN          NaN                 NaN
#
#                    Unnamed: 3 Unnamed: 4  Unnamed: 5     Unnamed: 6  \
# 0                         NaN        NaN         NaN            NaN
# 1                         NaN        NaN         NaN            NaN
# 2                         NaN      Kasir         NaN      Pelanggan
# 3                 Nama barang        NaN         NaN            NaN
# 4                         NaN     614032         NaN          Tunai
# 5           GOOD DAY TIRAMISU        NaN         NaN            NaN
# 6                    250ML/24        NaN         NaN            NaN
# 7     MILO UHT ACT-E 190ML/36        NaN         NaN            NaN
# 8        ULTRA MILK MIMI CKLT        NaN         NaN            NaN
# 9                    125ML/40        NaN         NaN            NaN
# 10                        NaN        NaN         NaN            NaN
# 11                        NaN     614032         NaN          Tunai
# 12        YAKULT PORORO TRPCL        NaN         NaN            NaN
# 13                  FRT 235ML        NaN         NaN            NaN
# 14                        NaN        NaN         NaN            NaN
# 15                        NaN     614032         NaN          Tunai
# 16       RINSO MOLTO LIQ SCHT        NaN         NaN            NaN
# 17                   42ML 6'S        NaN         NaN            NaN
# 18       RINSO LIQ MLTO ULTRA        NaN         NaN            NaN
# 19                  REF 800ML        NaN         NaN            NaN
# 20     DOWNY LIQ MYSTIQUE 6'S        NaN         NaN            NaN
# 21                       23ML        NaN         NaN            NaN
# 22    SO KLIN SOFT PINK 900ML        NaN         NaN            NaN
# 23               SANIA REF 2L        NaN         NaN            NaN
# 24         CAP LANG MKP 120ML        NaN         NaN            NaN
# 25           PEPSODENT EP GUM        NaN         NaN            NaN
# 26               HEALTH 160GR        NaN         NaN            NaN
# 27                        NaN        NaN         NaN            NaN
# 28                        NaN     614032         NaN          Tunai
# 29        SAMPOERNA A MILD 12        NaN         NaN            NaN
# ...                       ...        ...         ...            ...
# 9444                    400ML        NaN         NaN            NaN
# 9445   EVITA SPON MANDI ISI 2        NaN         NaN            NaN
# 9446    NATURIAN SHWR FRT FSN        NaN         NaN            NaN
# 9447                PUMP 600M        NaN         NaN            NaN
# 9448     ATTACK SOFTNR 6X48GR        NaN         NaN            NaN
# 9449    B&B BARBIE SHMP OLIVE        NaN         NaN            NaN
# 9450                    180ML        NaN         NaN            NaN
# 9451   DOWNY ANT BAC 25ML 6'S        NaN         NaN            NaN
# 9452               PANTENE NC        NaN         NaN            NaN
# 9453         FULLNS&LIFE 70ML        NaN         NaN            NaN
# 9454    MAMY POKO PANTS STD L        NaN         NaN            NaN
# 9455                     20/6        NaN         NaN            NaN
# 9456                      NaN        NaN         NaN  Halaman : 209
# 9457                      NaN        NaN         NaN            NaN
# 9458                      NaN        NaN         NaN            NaN
# 9459                      NaN        NaN         NaN            NaN
# 9460                      NaN      Kasir         NaN      Pelanggan
# 9461              Nama barang        NaN         NaN            NaN
# 9462               GULA LOKAL        NaN         NaN            NaN
# 9463     LE MINERALE 600ML/24        NaN         NaN            NaN
# 9464      MANDOM HAND SANTZER        NaN         NaN            NaN
# 9465               STBRY 50ML        NaN         NaN            NaN
# 9466         BAGUS STIK JRM B        NaN         NaN            NaN
# 9467   FROZZ BARLEY MINT 15GR        NaN         NaN            NaN
# 9468    LIFEBUOY BW LEMON BTL        NaN         NaN            NaN
# 9469                    100ML        NaN         NaN            NaN
# 9470    YUPI SEAWORLD 10GR/24        NaN         NaN            NaN
# 9471                      NaN        NaN         NaN            NaN
# 9472                      NaN        NaN         NaN            NaN
# 9473                      NaN        NaN         NaN  Halaman : 210
#
#       Unnamed: 7                       Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0            NaN                              NaN        NaN         NaN
# 1            NaN                              NaN        NaN         NaN
# 2            NaN                              NaN        NaN         NaN
# 3            NaN                        Hrg. Jual        Qty      Satuan
# 4            NaN                              NaN        NaN         NaN
# 5            NaN                             5850          1         PCS
# 6            NaN                              NaN        NaN         NaN
# 7            NaN                             3850          1         PCS
# 8            NaN                             2350          2         PCS
# 9            NaN                              NaN        NaN         NaN
# 10           NaN  Total Penjualan per Transaksi :        NaN         NaN
# 11           NaN                              NaN        NaN         NaN
# 12           NaN                            10150          1         PCS
# 13           NaN                              NaN        NaN         NaN
# 14           NaN  Total Penjualan per Transaksi :        NaN         NaN
# 15           NaN                              NaN        NaN         NaN
# 16           NaN                             5500          3         PCS
# 17           NaN                              NaN        NaN         NaN
# 18           NaN                            15275          2         PCS
# 19           NaN                              NaN        NaN         NaN
# 20           NaN                             5350          2         PCS
# 21           NaN                              NaN        NaN         NaN
# 22           NaN                            10850          1         PCS
# 23           NaN                            20450          1         PCS
# 24           NaN                            33350          1         PCS
# 25           NaN                            20650          1         PCS
# 26           NaN                              NaN        NaN         NaN
# 27           NaN  Total Penjualan per Transaksi :        NaN         NaN
# 28           NaN                              NaN        NaN         NaN
# 29           NaN                            11200          3         PCS
# ...          ...                              ...        ...         ...
# 9444         NaN                              NaN        NaN         NaN
# 9445         NaN                            10250          1         PCS
# 9446         NaN                            26600          1         PCS
# 9447         NaN                              NaN        NaN         NaN
# 9448         NaN                             5400          1         PCS
# 9449         NaN                            10350          1         PCS
# 9450         NaN                              NaN        NaN         NaN
# 9451         NaN                             5350          1         PCS
# 9452         NaN                            10100          1         PCS
# 9453         NaN                              NaN        NaN         NaN
# 9454         NaN                            38000          1         PCS
# 9455         NaN                              NaN        NaN         NaN
# 9456         NaN                              NaN        NaN         NaN
# 9457         NaN                              NaN        NaN         NaN
# 9458         NaN                              NaN        NaN         NaN
# 9459         NaN                              NaN        NaN         NaN
# 9460         NaN                              NaN        NaN         NaN
# 9461         NaN                        Hrg. Jual        Qty      Satuan
# 9462         NaN                            12600          1         PCS
# 9463         NaN                             2350          1         PCS
# 9464         NaN                             5550          1         PCS
# 9465         NaN                              NaN        NaN         NaN
# 9466         NaN                             5750          1         PCS
# 9467         NaN                             6600          1         PCS
# 9468         NaN                             7100          1         PCS
# 9469         NaN                              NaN        NaN         NaN
# 9470         NaN                              600          1         PCS
# 9471         NaN  Total Penjualan per Transaksi :        NaN         NaN
# 9472         NaN                Total Penjualan :        NaN         NaN
# 9473         NaN                              NaN        NaN         NaN
#
#      Unnamed: 11  Unnamed: 12 Unnamed: 13
# 0            NaN          NaN         NaN
# 1            NaN          NaN         NaN
# 2     Keterangan          NaN         NaN
# 3      Disk. [%]          NaN    Subtotal
# 4      Penjualan          NaN         NaN
# 5              0       5850.0         NaN
# 6            NaN          NaN         NaN
# 7              0       3850.0         NaN
# 8              0       4700.0         NaN
# 9            NaN          NaN         NaN
# 10           NaN      14400.0         NaN
# 11     Penjualan          NaN         NaN
# 12             0      10150.0         NaN
# 13           NaN          NaN         NaN
# 14           NaN      10150.0         NaN
# 15     Penjualan          NaN         NaN
# 16             0      16500.0         NaN
# 17           NaN          NaN         NaN
# 18             0      30550.0         NaN
# 19           NaN          NaN         NaN
# 20             0      10700.0         NaN
# 21           NaN          NaN         NaN
# 22             0      10850.0         NaN
# 23             0      20450.0         NaN
# 24             0      33350.0         NaN
# 25             0      20650.0         NaN
# 26           NaN          NaN         NaN
# 27           NaN     143050.0         NaN
# 28     Penjualan          NaN         NaN
# 29             0      33600.0         NaN
# ...          ...          ...         ...
# 9444         NaN          NaN         NaN
# 9445           0      10250.0         NaN
# 9446           0      26600.0         NaN
# 9447         NaN          NaN         NaN
# 9448           0       5400.0         NaN
# 9449           0      10350.0         NaN
# 9450         NaN          NaN         NaN
# 9451           0       5350.0         NaN
# 9452           0      10100.0         NaN
# 9453         NaN          NaN         NaN
# 9454           0      38000.0         NaN
# 9455         NaN          NaN         NaN
# 9456         NaN          NaN         NaN
# 9457         NaN          NaN         NaN
# 9458         NaN          NaN         NaN
# 9459         NaN          NaN         NaN
# 9460  Keterangan          NaN         NaN
# 9461   Disk. [%]          NaN    Subtotal
# 9462           0      12600.0         NaN
# 9463           0       2350.0         NaN
# 9464           0       5550.0         NaN
# 9465         NaN          NaN         NaN
# 9466           0       5750.0         NaN
# 9467           0       6600.0         NaN
# 9468           0       7100.0         NaN
# 9469         NaN          NaN         NaN
# 9470           0        600.0         NaN
# 9471         NaN     151575.0         NaN
# 9472         NaN   39437925.0         NaN
# 9473         NaN          NaN         NaN
#
# [9474 rows x 14 columns]

# %%
tanggal_trn = list()
barang_trn = list()
for i, j in zip(tanggal_tr, barang_tr):
    if len(j)!=0:
        j = ", ".join(j)
        tanggal_trn.append(i)
        barang_trn .append(j)
temp = list()
for i, tgl in enumerate (tanggal_trn):
    if tgl == "Maharani":
        tgl = tanggal_trn[i-1]
        temp.append(tgl)
    else:
        temp.append(tgl)
tanggal_trn = temp

# %%
dc = {
    'tanggal':tanggal_trn,
    'barang':barang_trn
}
df = pd.DataFrame.from_dict(dc)
df.to_excel("hasil.xlsx")
