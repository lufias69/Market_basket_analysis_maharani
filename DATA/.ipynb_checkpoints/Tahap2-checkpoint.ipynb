# %%
import pandas as pd

# %%
foo = pd.read_excel("hasil_3+tambahan.xlsx")
foo
# Out:
#         Unnamed: 0     tanggal  \
# 0                0  01/11/2018
# 1                1  01/11/2018
# 2                2  01/11/2018
# 3                3  01/11/2018
# 4                4  01/11/2018
# 5                5  01/11/2018
# 6                6  01/11/2018
# 7                7  01/11/2018
# 8                8  01/11/2018
# 9                9  01/11/2018
# 10              10  01/11/2018
# 11              11  01/11/2018
# 12              12  01/11/2018
# 13              13  01/11/2018
# 14              14  01/11/2018
# 15              15  01/11/2018
# 16              16  01/11/2018
# 17              17  01/11/2018
# 18              18  01/11/2018
# 19              19  01/11/2018
# 20              20  01/11/2018
# 21              21  01/11/2018
# 22              22  01/11/2018
# 23              23  01/11/2018
# 24              24  01/11/2018
# 25              25  01/11/2018
# 26              26  01/11/2018
# 27              27  01/11/2018
# 28              28  01/11/2018
# 29              29  01/11/2018
# ...            ...         ...
# 414439      414439  14/02/2016
# 414440      414440  14/02/2016
# 414441      414441  14/02/2016
# 414442      414442  14/02/2016
# 414443      414443  14/02/2016
# 414444      414444  14/02/2016
# 414445      414445  14/02/2016
# 414446      414446  14/02/2016
# 414447      414447  14/02/2016
# 414448      414448  14/02/2016
# 414449      414449  14/02/2016
# 414450      414450  14/02/2016
# 414451      414451  14/02/2016
# 414452      414452  14/02/2016
# 414453      414453  14/02/2016
# 414454      414454  14/02/2016
# 414455      414455  14/02/2016
# 414456      414456  14/02/2016
# 414457      414457  14/02/2016
# 414458      414458  14/02/2016
# 414459      414459  14/02/2016
# 414460      414460  14/02/2016
# 414461      414461  14/02/2016
# 414462      414462  14/02/2016
# 414463      414463  14/02/2016
# 414464      414464  14/02/2016
# 414465      414465  14/02/2016
# 414466      414466  14/02/2016
# 414467      414467  14/02/2016
# 414468      414468  14/02/2016
#
#                                                    barang
# 0       WALLS PP TWITSER, SILVER QUEEN ALMOND, WALL'S ...
# 1       ^NESTLE PURE LIFE, ^^NESTLE PURE LIFE, AQUA CL...
# 2                                   ^ADES NATURAL 1.5L/12
# 3       LAURIER RLX NIGHT 30CM, NISSIN GEKIKARA RAMEN,...
# 4       ^^SUNLIGHT LIME REFF, ^SUPERPELL GREEN REF, CU...
# 5       NISSIN VEGETABLE, ZEE UHT UP&GO COK, ^^AQUA 60...
# 6       KARTIKA SIRUP, ^^SANIA REF 2L/6 #, CUSSONS KID...
# 7       SO KLIN LIQ VIOBLSM, ENZIM MINT 100ML, LUX TS ...
# 8                   SUPERPELL YELLOW, ^^NICE POP UP 200'S
# 9                                            GG. SURYA 12
# 10                                      KDS SUPER POPCORN
# 11                                      ZEE UHT UP&GO COK
# 12                    SWEETY FIT PANTS, CAP LANG MKP 60ML
# 13      ^^SANIA REF 2L/6 #, BANG-BANG SHAVE IT, TINI W...
# 14      MILO COMBO PACK 32GR, WONG COCO PUDING, TONG T...
# 15                                       WALLS PP TWITSER
# 16                                    WALLS SALERO MANGGA
# 17      ^^INDOMIE GORENG, ^^INDOMIE AYAM SPECIAL, SEDA...
# 18                                TEH KOTAK APEL 300ML/24
# 19      CERELAC BRS MRH&SUSU, SUN BSC MARIE 80GR, ^^FR...
# 20                                    HERS PROTEX SC WING
# 21                     SARIMI TERI PEDAS, SUKSES MIE AYAM
# 22                                       DJARUM SUPER MLD
# 23      ^^SANIA REF 2L/6 #, ^^BENDERA SKM BKM, ^^BENDE...
# 24                             ^BENDERA UHT, MOMOGI STICK
# 25                                  POCARI SWEAT 900ML/15
# 26                                       SWEETY FIT PANTS
# 27                                  GG. SIGNATURE MILD 16
# 28                                      DUNHILL FILTER 16
# 29      NICE TRVEL PACK 60'S/90, ^MILO UHT ACT-E 190ML...
# ...                                                   ...
# 414439  SILVER QUEN WHT, YAKULT 65ML, TRENZ PSG KEJU 7...
# 414440  MOLTO TRIKA PINK NEW, LERVIA MILK SOAP 90GR, S...
# 414441  BENDERA CKLT BTL, ULTRA MILK MIMI CKLT, WONG C...
# 414442                                HI TOP HAIR DYE LOT
# 414443  SEDAP MI GRNG AYM, SO KLIN SOFT PEACH REF, SO ...
# 414444  KDS PC CAMPUR 140GR/32, TARO NET PPT BBQ, NISS...
# 414445                                     GAJAH KCG ATOM
# 414446                                    BENDERA SKM BKM
# 414447  TELUR AYAM, BIMOLI KLASIK REFF 2LT, INDOFOOD F...
# 414448  NICE FAC REF 200'S, ULTRA MILK UHT CKLT, HEAD ...
# 414449  DEL MONTE EXTRA HOT, SILVER QUEN CASHEW, SILVE...
# 414450  TOYS, TERIGU KUNCI BIRU, LE MINERALE 600ML/24,...
# 414451  INDOMIE KRTG AYM PGG, BANGO KCP MNS REF, DANCO...
# 414452  RISO ORGNK LONG GRAIN, ANLENE ONE DAY CKLT, GU...
# 414453                                  WALL'S PP TORNADO
# 414454                               ROMA MALKIS ABON FAM
# 414455  KING COCO CUBES, WALL'S PP TRICO/48, WALL'S PP...
# 414456  POCARI SWEAT 500ML, WONG COCO SARI KLPA, TELUR...
# 414457  SO KLIN LIQ SOFTRGNT, DETTOL SOAP ACTV 110GR, ...
# 414458  JETZ CKLT FIESTA 15GR/60, DOWNY SUNRISE FRESH,...
# 414459                                 SILVER QUEN CHUNKY
# 414460  SPRITE 390 ML/12, NUTRIJELL MELON 15GR, WONG C...
# 414461                                       VIP LPS TARA
# 414462                                 VAPE AER ONE TOUCH
# 414463  TELUR ASIN, BIMOLI KLASIK REFF 1LT, WONG COCO ...
# 414464                                   LAGIE CHOC.BANGO
# 414465  TELUR ASIN, TELUR ASIN BU ANIK, TIM TAM CHO VA...
# 414466                                         TELUR AYAM
# 414467  NESTLE PURE LIFE, FRESTEA JSMN LOW, HANSAPLAST...
# 414468  HIT OILSPRAY REF 700ML, HIT POMPA PLASTIK, BAG...
#
# [414469 rows x 3 columns]

# %%
tanggal = foo['tanggal'].tolist()
barang  = foo['barang'].tolist()

temp_t = list()
temp_b = list()
temp_b_lower = list()
iterasi = 0
for i, j in zip(tanggal,barang):
    if i == "Laporan Data Penjualan Per Transaksi" or i == 'Maharani':
        i = tanggal[iterasi-1]
        if i == "Laporan Data Penjualan Per Transaksi" or i == 'Maharani':
            i = tanggal[iterasi-2]
    i = i.split("/")
    try:
        i[0],i[2] = i[2],i[0]
    except:
        print(iterasi)
        print(i)
    temp_t.append("-".join(i))
    j = j.replace("^","").replace("#","").replace("'","").replace('"','')
    temp_b.append(j)
    temp_b_lower.append(j.lower())
    iterasi+=1
dic = {
    "tanggal":temp_t,
    "barang":temp_b
} 

df = pd.DataFrame(dic)
df.to_excel("hasil_akhir2.xlsx")

# %%
id = 1
file = open("insert_data.sql","w")
file.write("INSERT INTO `transaksi`(id, transaction_date,produk)\n")
file.write("VALUES\n")
for tgl, brg in zip(temp_t,temp_b):
    file.write('({},"{}","{}"),\n'.format(id, tgl, brg))
    id+=1
file.write(";")
file.close()
