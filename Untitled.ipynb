# %%
import pandas as pd
from datetime import datetime
from fix_namabarang import fix

# %%
from datetime import datetime

date_str2 = '6/6/18'

# Define dates as datetime objects
date_dt2 = datetime.strptime(date_str2, '%m/%d/%y').date()
print(date_dt2)
# Out:
# 2018-06-06

# %%
import os

path = r'D:\github\python\sona\DATA\all'

files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.xls' in file:
            files.append(os.path.join(r, file))

for f in files:
    print(f)
# Out:
# D:\github\python\sona\DATA\all\09-15 april 2018.xls
# D:\github\python\sona\DATA\all\1-08 april 2018.xls
# D:\github\python\sona\DATA\all\1-4 november 2018.xls
# D:\github\python\sona\DATA\all\10-16 JULI 2017.xls
# D:\github\python\sona\DATA\all\11-17 jan 2016.xls
# D:\github\python\sona\DATA\all\12-18 november 2018.xls
# D:\github\python\sona\DATA\all\13-19 feb 2017.xls
# D:\github\python\sona\DATA\all\16-22 april 2018.xls
# D:\github\python\sona\DATA\all\19-25 november 2018.xls
# D:\github\python\sona\DATA\all\20-28 feb 2017.xls
# D:\github\python\sona\DATA\all\23-30 april 2018.xls
# D:\github\python\sona\DATA\all\26-30 november 2018.xls
# D:\github\python\sona\DATA\all\5-11 november 2018.xls
# D:\github\python\sona\DATA\all\PENJUALAN 01-03 JUNI 2018.xls
# D:\github\python\sona\DATA\all\PENJUALAN 01-05 JUNI 2016.xls
# D:\github\python\sona\DATA\all\PENJUALAN 01-06 MEI 2018.xls
# D:\github\python\sona\DATA\all\PENJUALAN 01-07 AGUSTUS 2016.xls
# ...

# %%
foo = pd.read_excel(r"D:\github\python\sona\DATA\all\penjualan 01-09 september 2018.xls")
# Out:
# WARNING *** file size (4400552) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
foo
# Out:
#                                    Maharani    Unnamed: 1          Unnamed: 2  \
# 0      Laporan Data Penjualan Per Transaksi           NaN                 NaN
# 1               Tanggal cetak : 02 Mei 2019           NaN                 NaN
# 2                                   Tanggal           NaN        No.Transaksi
# 3                                       NaN   Kode Barang                 NaN
# 4                                01/09/2018           NaN  003012018090100094
# 5                                         1  8512167promo                 NaN
# 6                                       NaN           NaN                 NaN
# 7                                       NaN           NaN                 NaN
# 8                                01/09/2018           NaN  003012018090100185
# 9                                         1       8512120                 NaN
# 10                                        2       8512896                 NaN
# ...

# %%
# foo = pd.read_excel(al)
# tangal = foo["Maharani"].tolist()
# nomer_transaksi = foo["Unnamed: 2"].tolist()
# nama_barang = foo["Unnamed: 3"].tolist()

# %%
barang_tr = list()
tanggal_tr = list()
transaksi = list()

for al in files:
#     al = folder+"/"+al
    foo = pd.read_excel(al)
    tangal = foo["Maharani"].tolist()
    nomer_transaksi = foo["Unnamed: 2"].tolist()
    nama_barang = foo["Unnamed: 3"].tolist()
    for i, j, k in zip(tangal, nomer_transaksi, nama_barang):
        if k != "nan ": #and i == "nan":
    #         print(i, "|",j,"|", k)
            if type(i) is not float:
                if type(i) == int:
    #                 print(i)
                    transaksi.append(k)
                elif type(i) is str:
    #                 print(i)
                    barang_tr.append(transaksi)
                    tanggal_tr.append(i)
                    transaksi=list()
# Out:
# WARNING *** file size (3401810) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (3924663) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (2181859) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (2632274) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (2404836) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (3423074) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (2674277) not 512 + multiple of sector size (512)
# ...

# %%
barang_tr1 = barang_tr
tanggal_tr1 = tanggal_tr
transaksi1 = transaksi #658725

# barang_tr = barang_tr1
# tanggal_tr = tanggal_tr1
# transaksi = transaksi1
print(len(tanggal_tr))
print(len(barang_tr))
# Out:
# 683204
# 683204

# %%
tanggal_trn = list()
bukan = list()
barang_trn = list()
for i, j in zip(tanggal_tr, barang_tr):
    if len(j)!=0:
        j = ", ".join(j)
        j = j.replace("^","").replace('"',"").replace(']',"")
        j = j.lower()
        j = fix.fixNamaBarangAll(j)
        tanggal_trn.append(i)
        barang_trn .append(j)
temp = list()
count = 0
for i, tgl in enumerate (tanggal_trn):
    if tgl == 'Maharani' or tgl == 'Laporan Data Penjualan Per Transaksi' or tgl == 'Maharani':
#         print(barang_trn[i])
        tanggal_trn[i]=tanggal_trn[i-2]
        count+=1
    else:
        pass
count
# Out:
# 61715

# %%
for i, tgl in enumerate(tanggal_trn):
    if type(i) is float:
        print(i)
    t = tgl.split("/")
    try:
        t[0],t[2] = t[2],t[0]
#         print(t)
        t = "-".join(t)
        tanggal_trn[i]=t
    except:
        print(tgl)
#         pass

# %%
print(len(barang_trn))
print(len(tanggal_trn))
# Out:
# 429832
# 429832

# %%
dc = {
    'tanggal':tanggal_trn,
    'barang':barang_trn
}
df = pd.DataFrame.from_dict(dc)
df.to_excel("hasil_all_3.xlsx")
df
# Out:
#            tanggal                                             barang
# 0       2018-04-09            susu,minuman rasa,susu,snack,pasta gigi
# 1       2018-04-09  snack,minyak goreng,mie instan,mie instan,alat...
# 2       2018-04-09                                    obat nyamuk,kue
# 3       2018-04-09                            tisu,sabun wajah,shampo
# 4       2018-04-09                                              snack
# 5       2018-04-09                       snack,mie instan,snack,telur
# 6       2018-04-09                                               gula
# 7       2018-04-09                                         susu,snack
# 8       2018-04-09                                            es krim
# 9       2018-04-09                                        air mineral
# 10      2018-04-09                                  deterjen,deterjen
# 11      2018-04-09           pembalut,tisu,kosmetik,sabun mandi,snack
# ...

# %%
df[429827:429828]
# Out:
#            tanggal            barang
# 429827  2016-02-14  LAGIE CHOC.BANGO

# %%
# tanggal_trn = list()
# bukan = list()
# barang_trn = list()
# for i, j in zip(tanggal_tr, barang_tr):
#     if len(j)!=0:
#         j = ", ".join(j)
#         j = j.replace("^","")
#         tanggal_trn.append(i)
#         barang_trn .append(j)
# temp = list()
# for i, tgl in enumerate (tanggal_trn):
#     if tgl == 'Maharani' or tgl == 'Laporan Data Penjualan Per Transaksi' or tgl == 'Maharani':
# #         print(tgl)
#         if tanggal_trn[i-1] != 'Maharani' and tanggal_trn[i-1] != 'Laporan Data Penjualan Per Transaksi':
#             tgl = tanggal_trn[i-1]
#             tgl = tgl.split("/")
#             tgl[0],tgl[2] = tgl[2],tgl[0]
#             tgl = "-".join(tgl)
#             temp.append(tgl)
#         else:
#             try:
#                 tgl = tanggal_trn[i+1]
#                 tgl = tgl.split("/")
#                 tgl[0],tgl[2] = tgl[2],tgl[0]
#                 tgl = "-".join(tgl)
#                 temp.append(tgl)
#             except:
#                 if tgl == 'Maharani':
#                     tgl = tanggal_trn[i-2]
#                     tgl = tgl.split("/")
#                     tgl[0],tgl[2] = tgl[2],tgl[0]
#                     tgl = "-".join(tgl)
#                     temp.append(tgl)
#                     print(tgl)
#     else:
#         if "-" in tgl:
#             temp.append(tgl)
            
# #         tgl = tgl.split("/")
# #         tgl[0],tgl[2] = tgl[2],tgl[0]
# #         tgl = "-".join(tgl)
#         elif "/" in tgl:
#             temp.append(tgl)
#             print(tgl)
#             tgl = tgl.split("/")
#             tgl[0],tgl[2] = tgl[2],tgl[0]
#             tgl = "-".join(tgl)
#             temp.append(tgl)
#         else:
#             print(tgl)
#             temp.append(tgl)
# #     try:
# #         tgl = datetime.strptime(tgl, '%d/%m/%y').date()
# #     except:
# #         print(tgl)
# #     tgl = tgl.split("/")
# #     try:
# #         tgl[0],tgl[2] = tgl[2],tgl[0]
# #     except:
# #         bukan.append("".join(tgl))
# tanggal_trn = temp

# %%
# len(barang_trn)

# %%
# set(bukan)

# %%
# dc = {
#     'tanggal':tanggal_trn,
#     'barang':barang_trn
# }
# df = pd.DataFrame.from_dict(dc)
# df.to_excel("hasil_all_2.xlsx")
# df

# %%
# print(len(tanggal_trn))
# print(len(barang_trn))
