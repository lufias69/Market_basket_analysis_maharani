# %%
import pandas as pd
data = pd.read_excel("nama_produk.xlsx")
data

nama = data['nama produk'].tolist()
ganti = data['ganti'].tolist()

dictionary = dict(zip(nama, ganti))
dictionary

def fixNamaBarangAll(ls):
    ls = ls.split(",")
    for i, kt in enumerate(ls):
        try:
            ls[i] = dictionary[kt]
        except:
            pass
    return ",".join(ls)

def fixNamaBarang(ls):
    try:
        ls = dictionary[ls]
    except:
        pass
    return ls
# Out:
# {'wings biru 500 320gr/30': 'sabun cuci',
#  "tessa tp 11 50's": nan,
#  '2tang celup black tea': 'teh',
#  '2tang celup jasmine': 'teh',
#  '2tang celup van tea': 'teh',
#  '2tang jasmine scht': 'teh',
#  'abc asam jawa 250ml/24': 'soft drink',
#  'abc exo chonomalt': 'soft drink',
#  'abc exo milk coffee': 'soft drink',
#  'abc inst white mocca': 'soft drink',
#  'abc jambu juice': 'soft drink',
#  'abc jambu juice 1000ml': 'soft drink',
#  'abc jambu juice 250ml': 'soft drink',
#  'abc kacang hijau juice': 'soft drink',
#  'abc kcp asin 133ml': 'kecap',
#  'abc kcp manis 275ml': 'kecap',
#  'abc kcp manis 620ml': 'kecap',
#  'abc kcp mns 135ml': 'kecap',
#  'abc kcp mns gold blac': 'kecap',
#  'abc kcp mns ref 580ml': 'kecap',
#  'abc kcp mns reff 225ml': 'kecap',
#  'abc kcp mns reff 80ml': 'kecap',
#  'abc kcp pdas 135gr': 'kecap',
#  'abc kcp pdas 135ml': 'kecap',
#  'abc kcp pds 275ml': 'kecap',
#  'abc kecap gold 135gr': 'kecap',
#  "abc kopi susu 5's 32gr": 'soft drink',
#  'abc leci juice 250ml': 'soft drink',
#  'abc mango juice 250ml': 'soft drink',
#  'abc mckrl cabe 155gr': 'bumbu',
#  'abc mckrl extr pedas': 'bumbu',
#  'abc mckrl saua tmt': 'bumbu',
#  'abc mcrl saos tomat': 'saos',
#  'abc mi aym bwg 70gr/40': 'mie instan',
#  'abc mi cup aym bwg': 'mie instan',
#  'abc mi cup baso sapi': 'mie instan',
#  'abc mi cup rs soto': 'mie instan',
#  'abc mi pds grg limau': 'mie instan',
#  'abc mi slr pds aym grg': 'mie instan',
#  'abc mi slr pds cup grg': 'mie instan',
#  'abc mi slr pds gl aym': 'mie instan',
#  'abc mi slr pds gulai': 'mie instan',
#  'abc mi slr pds smr aym': 'mie instan',
#  'abc mi slr pds sop tmt': 'mie instan',
#  'abc mie  sup tomat pds': 'mie instan',
#  'abc mie ayam pedas': 'mie instan',
#  "abc mix 25gr 10's": 'minuman saset',
#  "abc mocca 5's 32gr": 'minuman saset',
#  'abc mr.jussie choco': 'soft drink',
#  'abc mr.jussie jeruk': 'soft drink',
#  'abc mr.jussie jmb bj': 'soft drink',
#  'abc mr.jussie+susu mgg': 'soft drink',
#  'abc mr.jussie+susu org': 'soft drink',
#  'abc mr.jussie+susu stw': 'soft drink',
#  'abc myk wijen 195ml': 'bumbu',
#  'abc orange juice': 'soft drink',
#  'abc sambal trasi 200gr': 'sambel instan',
#  "abc sambl terasi 10's": 'sambel instan',
#  'abc saos tmt 135ml': 'saos tomat',
#  'abc saos tmt 340ml': 'saos tomat',
#  'abc saos tomat 275ml': 'saos tomat',
#  'abc sari kcg hju 200ml': 'soft drink',
#  'abc sari kcg hju 250ml': 'soft drink',
#  'abc saus tiram 135ml': 'saus tiram',
#  'abc saus tiram 195ml': 'saus tiram',
#  'abc saus tmt 24x10gr': 'saus tiram',
#  'abc smbl asli 135ml': 'sambel instan',
#  'abc smbl asli 24x10gr': 'sambel instan',
#  'abc smbl asli 275ml btl': 'sambel instan',
#  'abc smbl asli 340ml': 'sambel instan',
#  'abc smbl asli pch 80gr': 'sambel instan',
#  'abc smbl aym grg 135ml': 'sambel instan',
#  'abc smbl ext pds 135ml': 'sambel instan',
#  'abc smbl ext pds 275ml': 'sambel instan',
#  'abc smbl ext pds 335ml': 'sambel instan',
#  'abc smbl ext pds pch': 'sambel instan',
#  'abc smbl masak 190gr': 'sambel instan',
#  'abc smbl mns pds 135ml': 'sambel instan',
#  'abc squash orange': 'sirup',
#  'abc srdn chili saus': 'ikan sarden',
#  'abc srdn ex.hot 155gr': 'ikan sarden',
#  'abc srdn ex.hot 425gr': 'ikan sarden',
#  'abc srdn saus tmt': 'ikan sarden',
#  'abc srp spcl grd mln': nan,
#  "abc stmj 28gr 5's": nan,
#  'abc susu bntl kedelai': nan,
#  'abc susu kedelai 200ml': nan,
#  'abc terasi udang': nan,
#  'abc white coffe 27gr': 'minuman saset',
#  "abc white instant 10's": 'minuman saset',
#  'absolute fmnn hygn': nan,
#  'acne washing bar 80gr': nan,
#  'acnes crmy wash 50gr': nan,
#  'acnes sealing jell 9gr': nan,
#  'adem ching ku pet': nan,
#  "adem sari box 6's": nan,
#  'adem sari ching ku': nan,
#  'adem sari chingku': nan,
#  'adem sari chinku': nan,
#  'ades natural 1.5l/12': nan,
#  'ades natural 600ml/24': nan,
#  'ades royal 350ml': nan,
#  'ades xtra pet 1.5ml': nan,
#  'ae pia crispy coklat': 'kue',
#  'ae pia crispy kacang': 'kue',
#  'aice banana crispy/40': 'es krim',
#  'aice bingo/50': 'es krim',
#  'aice choc stick/bingo': 'es krim',
#  'aice chocholate': 'es krim',
#  'aice choco cokiees': 'es krim',
#  'aice choco crispy/30': 'es krim',
#  'aice choco cup/24': 'es krim',
#  'aice choco vanila/48': 'es krim',
#  'aice coffe crispy /40': 'es krim',
#  'aice conetaro/48': 'es krim',
#  'aice durian cup/12': 'es krim',
#  'aice durian stick': 'es krim',
#  'aice es segar/50': 'es krim',
#  'aice es sugar/50': 'es krim',
#  'aice funky/50': 'es krim',
#  'aice lidah hijau/60': 'es krim',
#  'aice mangga lowfat/30': 'es krim',
#  'aice mango slush/30': 'es krim',
#  'aice melon/40': 'es krim',
#  'aice miki miki': 'es krim',
#  'aice milk stick/ funky': 'es krim',
#  'aice milk stick/50': 'es krim',
#  'aice mochi durian': 'es krim',
#  'aice moci vanila/40': 'es krim',
#  'aice moci/40': 'es krim',
#  'aice nanas/50': 'es krim',
#  'aice obor/30': 'es krim',
#  'aice semangka/50': 'es krim',
#  'aice sesame crispy': 'es krim',
#  'aice strawberry': 'es krim',
#  'aice strawberry cup/24': 'es krim',
#  'aice sundae/24': 'es krim',
#  'aice sweet': 'es krim',
#  'aice toffe coffee/ kopi': 'es krim',
#  'aice waffle cokelat': 'es krim',
#  'ainie beras jepang': nan,
#  'ainie hbl goat milk': nan,
#  'ainie papaya soap 135gr': nan,
#  'ainie rice milk soap': nan,
#  'ainie sbn sirih': nan,
#  'air mancur madurasa': nan,
#  'aizhilang btl k a-8112e': nan,
#  'ajinomoto 100gr': 'penyedap rasa',
#  'ajinomoto 100gr/10': 'penyedap rasa',
#  'ajinomoto msg 180gr': 'penyedap rasa',
#  'ajinomoto msg 180gr/10': 'penyedap rasa',
#  'ajinomoto msg 250gr': 'penyedap rasa',
#  'ajinomoto msg 250gr/10': 'penyedap rasa',
#  'ajinomoto msg 250gr/12': 'penyedap rasa',
#  'ajinomoto msg 50gr/20': 'penyedap rasa',
#  'ajinomoto rp1000': 'penyedap rasa',
#  'akomo nuget 250gr': nan,
#  'al barokah aster': 'makanan ringan',
#  'al barokah bola': 'makanan ringan',
#  'al barokah cendol': 'makanan ringan',
#  'al barokah ceriping': 'makanan ringan',
#  'al barokah kacang': 'makanan ringan',
#  'al barokah kacang ijo': 'makanan ringan',
#  'al barokah kedelai': 'makanan ringan',
#  'al barokah kentang': 'makanan ringan',
#  'al barokah kripik': 'makanan ringan',
#  'al barokah krupuk': 'makanan ringan',
#  'al barokah kurma': 'makanan ringan',
#  'al barokah makroni': 'makanan ringan',
#  'al barokah nastar': 'makanan ringan',
#  'al barokah pilos': 'makanan ringan',
#  'al barokah putri': 'makanan ringan',
#  'al barokah sagon': 'makanan ringan',
#  'al barokah sakura': 'makanan ringan',
#  'al barokah singkong': 'makanan ringan',
#  'al barokah wafer': 'makanan ringan',
#  'al barokah wafer mini': 'makanan ringan',
#  'al barokah wafer stik': 'makanan ringan',
#  'al barokah widaran': 'makanan ringan',
#  'al- barokah': 'makanan ringan',
#  'al-barokah bem': 'makanan ringan',
#  'al-barokah bola': 'makanan ringan',
#  'al-barokah gem': 'makanan ringan',
#  'al-barokah kacang': 'makanan ringan',
#  'al-barokah kembang': 'makanan ringan',
#  'al-barokah krupuk': 'makanan ringan',
#  'al-barokah onde onde': 'makanan ringan',
#  'al-barokah pangsit': 'makanan ringan',
#  'al-barokah slay': 'makanan ringan',
#  'al-barokah sus kerang': 'makanan ringan',
#  'ale ale grape 200ml': nan,
#  'ale-ale fuji apple 200ml': nan,
#  'ale-ale grape 200ml/24': nan,
#  'ale-ale orange 200ml': nan,
#  'ale-ale orange 200ml/24': nan,
#  'ale-ale sirsak/24': nan,
#  'ale-ale strwbry': nan,
#  'ale-ale strwbry 200ml': nan,
#  'aloha kntg krtg keju': nan,
#  'alpenliebe krml 140gr': nan,
#  'alpenliebe strw 117gr': nan,
#  'alpine dark': nan,
#  'amanda margarin': nan,
#  'ambipur cpc aqua sk': nan,
#  'ambipur cpc pac air sk': nan,
#  'amidis 1500ml/12': nan,
#  'amidis 600ml/24': nan,
#  'amidis gelas dus': nan,
#  'amplop 310 am tali jaya': nan,
#  'amplop folio+tali grs': nan,
#  'andec boneeto cklt': nan,
#  'andec boneeto vnla': nan,
#  'andec bonneto choco': nan,
#  "angel cb baby 125's": nan,
#  "angel cb dws 100's": nan,
#  'anget sari jahe jrk': nan,
#  "anget sari kopi jahe 5's": nan,
#  'anget sari susu jahe': nan,
#  "anget sari susu jahe 5's": nan,
#  'anget sari wedang': nan,
#  'aning kacang atom k': nan,
#  'aning telur ikan asin': nan,
#  'anlene act van 600gr': nan,
#  'anlene actft 250gr': nan,
#  'anlene actft cklt': nan,
#  'anlene actft vnla': nan,
#  'anlene activit mocha': nan,
#  'anlene gold 100gr': nan,
#  'anlene gold 250gr': nan,
#  'anlene gold 600gr': nan,
#  'anlene gold cklt': nan,
#  'anlene gold mocha': nan,
#  'anlene gold van': nan,
#  'anlene gold vnla': nan,
#  'anlene one day cklt': nan,
#  'anlene one day vnla': nan,
#  'anlene polybag': nan,
#  'anlene uht cokelat': nan,
#  'anlene uht vanila': nan,
#  'anmum cklt 200gr': nan,
#  'anmum cklt 400gr': nan,
#  'anmum lacta cklt': nan,
#  'anmum materna moka': nan,
#  'anmum mtrna moka': nan,
#  'antangin bandrek bag': nan,
#  'antangin fit 15ml/5': nan,
#  'antangin ginger': nan,
#  'antangin ginger mint': nan,
#  'antangin honey mint': nan,
#  'antangin jrg 15ml': nan,
#  'antangin jrg 15ml/12': nan,
#  'antangin jrg tab': nan,
#  'antangin jrg tab/12': nan,
#  'antangin jrg tab/20': nan,
#  'antangin junior madu': nan,
#  'antangin permen': nan,
#  'antangin permen strg': nan,
#  'antangin prmn mocha': nan,
#  'antangin tea jahe': nan,
#  'antangin teajahe bag ': nan,
#  'antimo 10 tab': 'obat',
#  'antimo anak jeruk': 'obat',
#  'antimo anak jeruk 5ml': 'obat',
#  'antimo anak stbry': 'obat',
#  'antiplaque pg 75gr': nan,
#  'antis btl jeruk nipis': nan,
#  'antis btl spry jeruk': nan,
#  'antis timun 55 ml': nan,
#  'apache filter 12': nan,
#  'apache filter 16': nan,
#  'apache kretek 12': nan,
#  'apilo spot cho wfr': nan,
#  'appeton wg dws 900gr': nan,
#  'aqua 1500ml/12': 'air mineral',
#  'aqua 1500ml/12 ': 'air mineral',
#  'aqua 1500ml/12 #': 'air mineral',
#  'aqua 330ml/24': 'air mineral',
#  'aqua 600ml/24': 'air mineral',
#  'aqua 600ml/24  ': 'air mineral',
#  'aqua 600ml/24  #': 'air mineral',
#  'aqua click 450ml/24': 'air mineral',
#  'aqua click 750ml': 'air mineral',
#  'aqua click 750ml/18': 'air mineral',
#  'aqua galon 19l': 'air mineral',
#  'aqua galon isi ulang': 'air mineral',
#  'aqua gelas dus': 'air mineral',
#  'aqua kids boy 330ml': 'air mineral',
#  'aqua kids girl 330ml': 'air mineral',
#  'aquaria 1500ml': 'air mineral',
#  'aquaria 1500ml/12': 'air mineral',
#  'aquaria 600ml': 'air mineral',
#  'aquaria 600ml/24': 'air mineral',
#  'aquaria 600ml/24 ': 'air mineral',
#  'aquaria 600ml/24 #': 'air mineral',
#  'aquaria galon isi': 'air mineral',
#  'aquaria gelas dus': 'air mineral',
#  'aquarius btl 500ml': 'air mineral',
#  'aquarius btl 500ml/12': 'air mineral',
#  'aquarius btl 500ml/24': 'air mineral',
#  'ar-rayan parfum': 'parfum',
#  'ar-rayan parfum roll': 'parfum',
#  'ar-rayan parfum spray': 'parfum',
#  'ar-rayyan jan viere': 'parfum',
#  'ar-rayyan parfum': 'parfum',
#  'argo emping ktk': 'makanan ringan',
#  'argo pop corn': 'makanan ringan',
#  'asahi lap mobil': 'kanebo',
#  'asava sweet chili 60gr': 'makanan ringan',
#  'asepso antsptc soap': 'sabun anti septic',
#  'astor dbl cklt 50gr': 'makanan ringan',
#  'astor kero coklat/6': 'makanan ringan',
#  'astor single 15gr/12': 'makanan ringan',
#  'astor single 15gr/20': 'makanan ringan',
#  'astor vovo pelangi/6': 'makanan ringan',
#  'attack auto': 'deterjen',
#  'attack clean max': 'deterjen',
#  'attack clean maxim': 'deterjen',
#  'attack easy 1.2kg/8': 'deterjen',
#  'attack easy 700gr': 'deterjen',
#  'attack easy liquid': 'deterjen',
#  "attack easy p.blsm 6's": 'deterjen',
#  'attack easy p.blsm liq': 'deterjen',
#  "attack easy rmntc 6's": 'deterjen',
#  'attack easy rmntc liq': 'deterjen',
#  'attack easy rmtc liq': 'deterjen',
#  'attack easy romantc': 'deterjen',
#  'attack easy romtc': 'deterjen',
#  'attack jaz 1 cinta 1.8kg': 'deterjen',
#  'attack jaz 1 segar': 'deterjen',
#  'attack juz1 cinta': 'deterjen',
#  'attack juz1 segar': 'deterjen',
#  'attack romantic': 'deterjen',
#  'attack softener': 'deterjen',
#  'attack softener 1.2kg': 'deterjen',
#  'attack softener 450gr': 'deterjen',
#  'attack softener 800gr': 'deterjen',
#  'attack softnr 6x48gr': 'deterjen',
#  'attack violet': 'deterjen',
#  'attack violet 800gr': 'deterjen',
#  'aulia hbl bengkoang': nan,
#  'aulia hbl goat milk': nan,
#  'aulia hbl milky 600ml': nan,
#  "autan 10gr 6's sct": nan,
#  "autan 10gr 6's/24": nan,
#  "autan family 6's 8ml": nan,
#  "autan family 6's/24": nan,
#  "autan junior 6's 7ml": nan,
#  "autan junior 6's/24": nan,
#  'autan kids tube 50gr': nan,
#  'autan refresh tube': nan,
#  'autan ss tube 50gr': nan,
#  "avail day use biru 10's": nan,
#  'avail day use biru/10': nan,
#  "avail night merah 8's": nan,
#  'avail night merah/8': nan,
#  "avail night pink 8's": nan,
#  'avail pantyliner': nan,
#  'avail pantyliner hijau': nan,
#  'axe anarchy for her': nan,
#  'axe black 150ml / 12': nan,
#  'axe bs anarchy him': nan,
#  'axe bs apollo 150gr': nan,
#  'axe bs apollo 50ml': nan,
#  'axe bs dark tempt': nan,
#  'axe bs dark tmpttn': nan,
#  'axe bs provoke 50ml/24': nan,
#  'axe dark tempat+axe': nan,
#  'axe deo you cool': nan,
#  'axe ro performance': nan,
#  'axe ro signature': nan,
#  'axe score new 150ml/12': nan,
#  'axe signature edt': nan,
#  'axe you + axe ro urban': nan,
#  'azano napth 75gr': nan,
#  'b&b barbie shmp olive': nan,
#  'b&b barbie shmp pearl': nan,
#  'b&b kids col frutti': nan,
#  'b&b kids col raspbery': nan,
#  'b&b kids pwdr blossom': nan,
#  'b&b kids sg pack': nan,
#  'b&b kids smpo grape': nan,
#  'b&b kids smpo kiwi mln': nan,
#  'b&b kids smpo ornge': nan,
#  'b&b kids smpo strwbry': nan,
#  'b&b kids spry col kiwi': nan,
#  'b&b spry col tasmania': nan,
#  'baby finger': nan,
#  'baby happy l 20': nan,
#  'baby happy l-10': nan,
#  'baby happy m 20': nan,
#  'baby happy m-10': nan,
#  'bagus 150gr': nan,
#  'bagus 300gr': nan,
#  'bagus 35gr': nan,
#  'bagus 35gr/24': nan,
#  'bagus anti bau gel': nan,
#  'bagus anti bau lmri es': nan,
#  'bagus anti bau mbl': nan,
#  'bagus anti bau mobil': nan,
#  'bagus anti bau sepatu': nan,
#  'bagus bagelen tpls': nan,
#  'bagus balok cmpr b': nan,
#  'bagus beautymate': nan,
#  'bagus beautymate lux': nan,
#  'bagus bola-bola cklt': nan,
#  'bagus bolu smle tpls': nan,
#  'bagus borsalino': nan,
#  'bagus brownis krng': nan,
#  'bagus car fresh mori': nan,
#  'bagus cendol keju': nan,
#  'bagus chamais 32x21cm': nan,
#  'bagus cipir b': nan,
#  'bagus contong mini': nan,
#  'bagus crip bldo basah': nan,
#  'bagus criping': nan,
#  'bagus egg roll tpls': nan,
#  'bagus emping mns tpls': nan,
#  'bagus fresh oner': nan,
#  'bagus glint liq shoe': nan,
#  'bagus glint sneaker': nan,
#  'bagus glint sporge': nan,
#  'bagus jelly tpls': nan,
#  'bagus kacang bngkok': nan,
#  'bagus kacang bwg': nan,
#  'bagus kacang medan': nan,
#  'bagus kacang molen': nan,
#  'bagus kacang pds b': nan,
#  'bagus kacang utama b': nan,
#  'bagus kacang utm': nan,
#  'bagus kacang utm t': nan,
#  'bagus kapri ijo b': nan,
#  'bagus kapri ijo tpls': nan,
#  'bagus kapri tpg tpls': nan,
#  'bagus kapri tpng b': nan,
#  'bagus kapur ajaib': nan,
#  'bagus kara keju b': nan,
#  'bagus kara keju tpls': nan,
#  'bagus kara kps tpls': nan,
#  'bagus kara kulit b': nan,
#  'bagus kara kupas b': nan,
#  'bagus keciput tpls': nan,
#  'bagus kedelai b': nan,
#  'bagus kenanga b': nan,
#  'bagus kitchenmate': nan,
#  'bagus koin pedas': nan,
#  'bagus krupuk setan b': nan,
#  'bagus krupukpedas': nan,
#  'bagus kuping gajah b': nan,
#  'bagus kurma': nan,
#  'bagus kurma ktk pnjg': nan,
#  'bagus kurma ktk tgg': nan,
#  'bagus kurma toples': nan,
#  'bagus kurma tpls oval': nan,
#  'bagus kwaci mthr b': nan,
#  'bagus kwaci mthr tpls': nan,
#  'bagus lem super blue': nan,
#  'bagus lem super glue': nan,
#  'bagus mak rujak b': nan,
#  'bagus mak untir cmpr': nan,
#  'bagus mak usus b': nan,
#  'bagus mak usus cmpr b': nan,
#  'bagus makroni rjk b': nan,
#  'bagus makroni untir b': nan,
#  'bagus makroni usus': nan,
#  'bagus marneng b': nan,
#  'bagus mexico tpls': nan,
#  'bagus mie kremes 450gr': nan,
#  'bagus mie kremes b': nan,
#  'bagus mie lidi': nan,
#  'bagus morling b': nan,
#  'bagus nastar': nan,
#  'bagus nastar apel': nan,
#  'bagus nastar apel kju': nan,
#  'bagus nastar nanaas': nan,
#  'bagus nastar putri': nan,
#  'bagus neo razor': nan,
#  "bagus neo razor 2's": nan,
#  "bagus neo razor 5's": nan,
#  'bagus nina anion 33cm': nan,
#  'bagus nina day wing': nan,
#  'bagus nina dry fit': nan,
#  "bagus nina dry fit 10's": nan,
#  'bagus nina night wing': nan,
#  'bagus nina panty flrl': nan,
#  'bagus nina panty nat': nan,
#  'bagus nina soft care': nan,
#  'bagus nina softcare': nan,
#  'bagus opak medan b': nan,
#  'bagus pang-pang mns': nan,
#  'bagus pang-pang mns b': nan,
#  'bagus pang-pang pds': nan,
#  'bagus pang-pang pds b': nan,
#  'bagus para kamper': nan,
#  'bagus para kmpr 300gr': nan,
#  'bagus pastel tpls': nan,
#  'bagus permen tape': nan,
#  'bagus pilus aust b': nan,
#  'bagus pilus australi': nan,
#  'bagus pilus ikan b': nan,
#  'bagus pisang durian': nan,
#  'bagus polong jepang': nan,
#  'bagus polong jpg tpls': nan,
#  'bagus polong jpng b': nan,
#  'bagus potato campur': nan,
#  'bagus potato mini b': nan,
#  'bagus putri salju tpls': nan,
#  "bagus quarda 2's": nan,
#  "bagus razor x 1's": nan,
#  'bagus sabit b': nan,
#  'bagus sabit tpls': nan,
#  'bagus sale gulung': nan,
#  'bagus sale pisang b': nan,
#  'bagus seblak hot b': nan,
#  'bagus semprit tpls': nan,
#  'bagus sevon facial wp': nan,
#  'bagus sg delux s/12': nan,
#  'bagus sg superkid/s': nan,
#  'bagus shoe brush oval': nan,
#  'bagus sikat alami': nan,
#  'bagus sikat alami bag': nan,
#  'bagus sikat baju': nan,
#  'bagus sikat jas cekung': nan,
#  'bagus sikat lantai': nan,
#  'bagus stik bldo b': nan,
#  'bagus stik bwg tpls': nan,
#  'bagus stik jarum tpls': nan,
#  'bagus stik jrm b': nan,
#  'bagus sumpia tpls': nan,
#  'bagus sus asin tpls': nan,
#  'bagus sus cokelat': nan,
#  'bagus sus sayur tpls': nan,
#  "bagus toilet ball 4's": nan,
#  "bagus toilet ball 5's": nan,
#  "bagus toilet ball 6's": nan,
#  'bagus with case': nan,
#  'bakmi mewah': nan,
#  'bakmi mewah goreng': nan,
#  'bala-bala mil 500': nan,
#  'bang-bang share it': nan,
#  'bang-bang shave it': nan,
#  'bango bmb aym grng': nan,
#  'bango bmb tmpe thu': nan,
#  'bango kcp mns 135ml/48': nan,
#  'bango kcp mns 275ml/24': nan,
#  'bango kcp mns btl': nan,
#  'bango kcp mns pedas': nan,
#  'bango kcp mns ref': nan,
#  'bango kcp mns reff': nan,
#  'bango kecap manis': nan,
#  'bango pouch flatpack': nan,
#  'bantal kotak bkt 57': nan,
#  'bantal peang bpt 50': nan,
#  'barbara walden pink': nan,
#  'bask bs abslt': nan,
#  'bask bs spry cool 100ml': nan,
#  'baskom umum warna': nan,
#  "bat. abc biru 2's bsr": nan,
#  "bat. abc spr pwr 4's (r-6)": nan,
#  'bat. alkaline aa (lr06': nan,
#  'bat. alkaline aaa (lr03': nan,
#  "bat.abc biru 2's bsr": nan,
#  "bat.abc biru 2's tg": nan,
#  "bat.abc biru r-6 4's": nan,
#  "bat.abc power 2's bsr": nan,
#  "bat.abc spr pwr 4's kcl": nan,
#  "bat.alkaline aa 2's": nan,
#  "bat.alkaline aa 4's": nan,
#  'bat.alkaline aaa (4+2)': nan,
#  "bat.alkaline aaa 2's": nan,
#  'batita madu 800gr ': nan,
#  'bayclin fresh 100ml': nan,
#  'bayclin fresh 1l': nan,
#  'bayclin fresh 500ml': nan,
#  'bayclin lemon 500ml': nan,
#  'bayclin reg 100ml': nan,
#  'bayclin regular 200ml': nan,
#  'bayclin regular 500ml': nan,
#  'bayfresh everywhere': nan,
#  'bayfresh hang&go': nan,
#  'bayfresh mtc spry org': nan,
#  'baygon aer kuning': nan,
#  'baygon aer wtrbase': nan,
#  'baygon aerosol': nan,
#  'baygon alat+isi ulng': nan,
#  'baygon bakar green': nan,
#  'baygon bakar jumbo': nan,
#  'baygon bar nes 600ml': nan,
#  'baygon bar nes 750ml': nan,
#  "baygon db bakar 5's": nan,
#  'baygon elktrk cair': nan,
#  'baygon green max isi': nan,
#  'baygon isi cair nes': nan,
#  'baygon jumbo lav isi': nan,
#  'baygon lavndr 750ml': nan,
#  'baygon mat 30': nan,
#  'baygon mat 30 db': nan,
#  'baygon mat elect': nan,
#  'baygon mat isi ulg 60': nan,
#  'baygon mat lav 60': nan,
#  'baygon nat orange': nan,
#  'baygon obat srga': nan,
#  'baygon obt srngga': nan,
#  'baygon one push': nan,
#  'baygon pompa': nan,
#  'baygon spray blue': nan,
#  'baygon spray flower': nan,
#  'baygon spry kng 275ml': nan,
#  'baygon spry kng 600ml': nan,
#  'baygon spry lav 275ml': nan,
#  'baygon spry lav 600ml': nan,
#  'bdl papaya soap 135gr': nan,
#  'bear brand malt pth': nan,
#  'bear brand milk': nan,
#  'bear brand teh putih': nan,
#  'beauty active': nan,
#  'beauty active facial': nan,
#  'bebe rosy 60gr': nan,
#  'bebelac 3 madu 400gr': nan,
#  'bebelac 3 madu 800gr': nan,
#  'bebelac 3 van 800gr': nan,
#  'bebelac 3 vnla 400gr': nan,
#  'bebelac 4 cklt 400gr': nan,
#  'bebelac 4 madu 400gr': nan,
#  'bebelac 4 madu 800gr': nan,
#  'bebelac 4 vnla 400gr': nan,
#  'bebelac 4 vnla 800gr': nan,
#  'bebelove 1 200gr': nan,
#  'bebelove 1 400gr': nan,
#  'bebelove 1 800gr': nan,
#  'bebelove 2 200gr': nan,
#  'bebelove 2 400gr': nan,
#  'bebelove 2 800gr': nan,
#  'bedak salicyl dragon': nan,
#  'bee flower cklt rrt': nan,
#  'bee flower hijau rrt': nan,
#  'bee flower mrh rrt': nan,
#  'bella meises 225 gr': nan,
#  'bella meises 90 gr mix': nan,
#  'bella meises cklt 100gr': nan,
#  'bella meises warna 90': nan,
#  'bella meisses coklat': nan,
#  'bella meisses warna': nan,
#  'bellagio ds rave cltre': nan,
#  'bellagio ds stmina': nan,
#  'bellagio ds vntura': nan,
#  'bellagio ro rv': nan,
#  'bellagio ro stamina': nan,
#  'bellagio ro vntura': nan,
#  'bellagio spry col': nan,
#  'bellagio spry col rave': nan,
#  'belvita banana 80gr/24': nan,
#  'belvita bisc': nan,
#  'bendera 123 cklt 400gr': nan,
#  'bendera 123 cklt 800gr': nan,
#  'bendera 123 madu 200gr': nan,
#  'bendera 123 madu 400gr': nan,
#  'bendera 123 madu 800gr': nan,
#  'bendera 123 van 400gr': nan,
#  'bendera 123 van 800gr': nan,
#  'bendera 456 cklt 400gr': nan,
#  'bendera 456 cklt 800gr': nan,
#  'bendera 456 madu 200gr': nan,
#  'bendera 456 madu 400gr': nan,
#  'bendera 456 madu 800gr': nan,
#  'bendera 456 van 400gr': nan,
#  'bendera 456 van 800gr': nan,
#  'bendera cklt 400gr': nan,
#  'bendera cklt btl': nan,
#  'bendera cokelat can': nan,
#  'bendera coklat': nan,
#  'bendera coklat botol': nan,
#  'bendera cp cklt 1lt': nan,
#  'bendera full cream': nan,
#  'bendera full crm 400gr': nan,
#  'bendera full crm 800gr': nan,
#  'bendera gold can get': nan,
#  'bendera instan 400gr': nan,
#  'bendera instan 800gr': nan,
#  'bendera jelajah 123': nan,
#  'bendera karya 456': nan,
#  'bendera karya 456 van': nan,
#  'bendera low fat 1lt': nan,
#  'bendera madu 400gr': nan,
#  'bendera madu 800gr/18': nan,
#  'bendera milky cok btl': nan,
#  'bendera omela 387gr': nan,
#  'bendera pure farm cok': nan,
#  'bendera skm': nan,
#  'bendera skm  fc gold': nan,
#  'bendera skm bkm': nan,
#  'bendera skm bkm 385gr': nan,
#  'bendera skm bkm 560ml': nan,
#  'bendera skm bkm can': nan,
#  'bendera skm bkm putih': nan,
#  'bendera skm bkm scht': nan,
#  'bendera skm cklt': nan,
#  'bendera skm cklt 385gr': nan,
#  "bendera skm cok 6's": nan,
#  'bendera skm cokelat': nan,
#  'bendera skm coklat': nan,
#  'bendera skm gold': nan,
#  "bendera skm gold 6's": nan,
#  'bendera skm pch ckt': nan,
#  'bendera skm pch fc': nan,
#  'bendera skm putih': nan,
#  'bendera skm susujahe': nan,
#  'bendera strawbery': nan,
#  'bendera stwbry btl': nan,
#  'bendera tahap 1 200gr': nan,
#  'bendera tahap 1 400gr': nan,
#  'bendera tahap 1 800gr': nan,
#  'bendera tahap 2 200gr': nan,
#  'bendera tahap 2 400gr': nan,
#  'bendera tahap 2 800gr': nan,
#  'bendera uht': nan,
#  'bendera uht cho': nan,
#  'bendera uht cklt': nan,
#  'bendera uht ckt': nan,
#  'bendera uht coconut': nan,
#  'bendera uht kacang': nan,
#  "bendera uht kid's": nan,
#  'bendera uht low fat': nan,
#  'bendera uht strw': nan,
#  'bendera uht strwbry': nan,
#  'bendera uht van': nan,
#  'bendico cocoa 90gr': nan,
#  'beng beng maxx 32gr/12': nan,
#  'beng beng maxx 32gr/25': nan,
#  'beng-beng ckt 22gr/25': nan,
#  'beng-beng coklat': nan,
#  'beng-beng drink 30gr': nan,
#  'beng-beng peanut': nan,
#  'beng-beng white': nan,
#  'beras c4 biasa 5kg': nan,
#  'beras c4 super cap': nan,
#  'beras kepala merpati': nan,
#  'beras lele 5kg': nan,
#  'beras lele merpati': nan,
#  'beras lumba-lumba 5kg': nan,
#  'beras maknyus 5kg/5': nan,
#  'beras mentik 5kg': nan,
#  'beras merah (rs)': nan,
#  'beras merah 2 kg (u015)': nan,
#  'beras merah cap': nan,
#  'beras merah cap org': nan,
#  'beras merah premium': nan,
#  'beras mrh orgnk': nan,
#  'beras ngawiti mas': nan,
#  'beras ngawiti mas 5kg': nan,
#  'beras pak 2': nan,
#  'beras raja lele 5kg': nan,
#  'beras rj lele 2.5kg': nan,
#  'beras sania 5kg': nan,
#  'beras slip strawberry': nan,
#  'beras slyp lp 5kg': nan,
#  'beras slyp merpati 5kg': nan,
#  'beras slyp strawberry': nan,
#  'beras susu 60gr new': nan,
#  'beras tanak 5kg': nan,
#  'beras tanak 5kg/5': nan,
#  'beras tanak 5kg/8': nan,
#  'beras wangi merpati': nan,
#  'beras zakat 2': nan,
#  'betadine obat kumur': nan,
#  'betadine solution': nan,
#  'betadine solution 5ml': nan,
#  'bf chicken nugget': nan,
#  'bf chicken stick': nan,
#  'bf nugget ceria': nan,
#  'bh remaja liyimei 89': nan,
#  'bh remaja liyinei': nan,
#  'bieskies chesee 108gr/24': nan,
#  'bieskies coklat 108gr/24': nan,
#  'bieskies vanila 108gr/24': nan,
#  'big babol rasa tuti': nan,
#  'big babol rs strw': nan,
#  'big babol rs strw 22gr': nan,
#  'big babol rs tf 22gr': nan,
#  'big babol rs tf 22gr/20': nan,
#  'big babol strwbry': nan,
#  'big babol tf 120gr': nan,
#  'big cola 535ml/12': nan,
#  'big rs lime 535ml/12': nan,
#  'big rs orange 535ml/12': nan,
#  'big rs stbry 535ml/12': nan,
#  'bigbabol tutti fruti ': nan,
#  'bigen hair dye black': nan,
#  'bihun jagung padamu': nan,
#  'bihunku ayam bawang': nan,
#  'bihunku ayan bawang': nan,
#  'bihunku goreng': nan,
#  'bihunku soto special': nan,
#  'bimoli klasik btl 1lt': nan,
#  'bimoli klasik reff': nan,
#  'bimoli klasik reff 1lt': nan,
#  'bimoli klasik reff 2lt': nan,
#  'bimoli spc btl 1ltr': nan,
#  'bimoli spc btl 2ltr': nan,
#  'bimoli spc reff 1lt': nan,
#  'bimoli spc reff 2lt': nan,
#  'binder kecil': nan,
#  'bintang zero can': nan,
#  'bintang zero can 330ml': nan,
#  'bio miwon 200gr': nan,
#  'biore bf antiseptic': nan,
#  'biore bf antisptc reff': nan,
#  'biore bf bright care': nan,
#  'biore bf brirght care': nan,
#  'biore bf cherfull': nan,
#  'biore bf clear fresh': nan,
#  'biore bf freshy': nan,
#  'biore bf freshy blsm': nan,
#  'biore bf hygnc cool': nan,
#  'biore bf lively refres': nan,
#  'biore bf lively refresh': nan,
#  "biore bf men's spklng": nan,
#  'biore bf pleasure': nan,
#  'biore bf pure mild': nan,
#  'biore bf pure mild btl': nan,
#  'biore bf pure mild reff': nan,
#  'biore bf reff cherfull': nan,
#  'biore bf relax': nan,
#  'biore bf relaxing a': nan,
#  'biore bf relaxing reff': nan,
#  'biore bf rlxng 100ml': nan,
#  'biore bf rlxng btl': nan,
#  'biore bf rlxng reff': nan,
#  'biore bf sweet peach': nan,
#  'biore bf triple act bt': nan,
#  'biore bf triple act pc': nan,
#  'biore bf whtng btl': nan,
#  'biore bf whtng reff': nan,
#  'biore ff acne care': nan,
#  'biore ff acne care 40gr': nan,
#  'biore ff double scrb': nan,
#  'biore ff glowing': nan,
#  'biore ff pore&oil': nan,
#  'biore hbl ext rich moi': nan,
#  'biore hbl glowing': nan,
#  'biore hbl glowning': nan,
#  'biore hbl smoothie': nan,
#  'biore hbl smothie': nan,
#  'biore men ant ff ant': nan,
#  'biore men bf wht reff': nan,
#  'biore men dbl scrb': nan,
#  'biore men facial anti': nan,
#  'biore men facial deet': nan,
#  'biore men faciali acne': nan,
#  'biore men ff anti acne': nan,
#  'biore men ff double': nan,
#  'biore men ff wht': nan,
#  "biore men's ff acne": nan,
#  "biore men's ff scrub": nan,
#  "biore men's fs oil": nan,
#  "biore men's fs white": nan,
#  'biore mur daily color': nan,
#  'biore pore pack': nan,
#  'biore rich noirish': nan,
#  'biore softsoap ksgran': nan,
#  'biore softsoiap smrbk': nan,
#  'biosol karbol pine': nan,
#  'bisc ember 1 rasa': nan,
#  'bisc ember 1 rasa btr': nan,
#  'bisc ember 1 rasa wht': nan,
#  'bisc ember assorted/6': nan,
#  'biskitop assorted': nan,
#  'biskitop assorted fam': nan,
#  'biskitop banana 350gr': nan,
#  'biskitop box wafer': nan,
#  'biskitop chocolate': nan,
#  'biskitop coconut': nan,
#  'biskitop coklat 350gr': nan,
#  'biskitop durian 400gr': nan,
#  'biskitop ember assrtd': nan,
#  'biskitop ember black': nan,
#  'biskitop ember btr cks': nan,
#  'biskitop ember orange': nan,
#  'biskitop ember peanut': nan,
#  'biskitop orange 400gr': nan,
#  'biskitop peanut 400gr': nan,
#  'biskitop potato 400gr': nan,
#  'biskitop sandwich van': nan,
#  'biskitop wafer stick': nan,
#  'biskitop xtr long stk': nan,
#  'biskota wafer stick': nan,
#  'biskota wfr cklt 500gr': nan,
#  'biskota wfr strw 500gr': nan,
#  'biskoto asstd box cok': nan,
#  'biskotto potato': nan,
#  'biskotto seaweed': nan,
#  'biskuat bolu cklt': nan,
#  'biskuat bolu coklat': nan,
#  'biskuat bolu pndn': nan,
#  'biskuat energi': nan,
#  'biskuat energi 65g/60': nan,
#  'biskuat energi 73.5g/60': nan,
#  'biskuat energi cklt': nan,
#  'biskuat energi jumbo': nan,
#  'biskuat sandw cho': nan,
#  'black plus dye 6ml': nan,
#  'blaster neaplt 200gr': nan,
#  'blaster pop 9gr': nan,
#  'blaster x-tra coklat': nan,
#  'blue band': nan,
#  'blue band c&c promo': nan,
#  'blue band serbaguna': nan,
#  "bodrex extra 4's": nan,
#  "bodrex migra 4's/25": nan,
#  "bodrex tab 10's": nan,
#  "bodrex tab 10's/10": nan,
#  'bodrexin jeruk 10 tab': nan,
#  'bodrexin jeruk tab': nan,
#  'bodyspray posh men': nan,
#  "bola isi 10's": nan,
#  "bola isi 18's": nan,
#  "bola isi 24's": nan,
#  "bola isi 50's": nan,
#  'bon cabe level 15 scht': nan,
#  'bon cabe orgl level 15': nan,
#  'bon cabe orgnl 22.5gr': nan,
#  'bon cabe orgnl 6x7.5gr': nan,
#  'bon cabe orgnl btl/24': nan,
#  'bon cabe rs teri 7.5gr': nan,
#  'bon cabe rs teri btl/24': nan,
#  'boneeto uht cok': nan,
#  'boneto cookies &': nan,
#  'boneto polybag': nan,
#  'boneto uht cho choc': nan,
#  'boneto uht chobry': nan,
#  'boneto uht strbry': nan,
#  'boneto uht van twstr': nan,
#  'bontea green': nan,
#  'bontea green apple': nan,
#  'bontea green lemon': nan,
#  'boom jrk nps 550gr': nan,
#  'boom putih 550gr/12': nan,
#  'boom pwdr 500gr': nan,
#  'boplen tizo gel tg': nan,
#  'botan mckrl tmt saus': nan,
#  'botan srdn tmt saus': nan,
#  'botol air 600ml (aj)': nan,
#  'botol air 800ml (aj)': nan,
#  'botol air brasil 900ml': nan,
#  'botol air germen 500ml': nan,
#  'botol air takuma': nan,
#  'botol cat 4/5 oz dbc023': nan,
#  'botol cat 8/9 oz dbc024': nan,
#  'botol dino 5 oz dbc025': nan,
#  'botol dino 9 oz dbc026': nan,
#  'botol kcp 7100 s': nan,
#  'botol kecap 7100 m (pj)': nan,
#  'botol kecap 7100l pj': nan,
#  'botol pahe 2 oz dbc001': nan,
#  'botol pahe 4 oz dbc002': nan,
#  'botol pahe 8 oz dbc003': nan,
#  'botol pp inova 2 oz': nan,
#  'botol sir brasil 500ml': nan,
#  'botol umix 240ml': nan,
#  'br cheezy bites 500gr/12': nan,
#  'br chicken stick': nan,
#  'brasso m/polish 100ml': nan,
#  'brasso m/polish 200ml': nan,
#  'brio potato prem': nan,
#  'brio potato prem 104gr': nan,
#  'brio potato premium': nan,
#  'buavita guava 1lt': nan,
#  'buavita juice sirsat': nan,
#  'buavita jus apel': nan,
#  'buavita jus apel 250ml': nan,
#  'buavita jus jambu': nan,
#  'buavita jus jeruk': nan,
#  'buavita jus jeruk 250ml': nan,
#  'buavita jus leci 250ml': nan,
#  'buavita jus mangga': nan,
#  'buavita orange 1lt': nan,
#  'buavita royal brokoli': nan,
#  'bubuk cabe 50gr': nan,
#  'bubuk kayu manis 50gr': nan,
#  'bubuk ketumbar 50gr': nan,
#  'bubuk lada hitam 50gr': nan,
#  'bubuk lada putih 50gr': nan,
#  "bugo krezz ayam 2's": nan,
#  'bugo krezz sapi pds': nan,
#  "bugo krezz sapi pds 2's": nan,
#  'bukaan botol duguna': nan,
#  'bukrim 5000 ant noda': nan,
#  'bukrim 5000 lemon': nan,
#  'bukrim merah 5000': nan,
#  'bukrim merah 5000 475gr': nan,
#  'bukrim oxyklin roman': nan,
#  'buku gambar': nan,
#  'buku gambar a3 mirage': nan,
#  'buku gambar a8': nan,
#  'bumbu nasi goreng': nan,
#  'bumbu nasi kuning': nan,
#  'bumbu rendang': nan,
#  'burung dara': nan,
#  'burung dara kering': nan,
#  'burung dara renteng': nan,
#  'burung dara urai': nan,
#  ...}
